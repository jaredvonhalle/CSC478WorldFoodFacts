# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import utilities as utils

# %%
data = pd.read_csv("world-food-facts/FoodFacts.csv")
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0,3,5,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print data.shape
data.head()
# Out:
# (65503, 159)
#                  code                                                url  \
# 0  000000000000012866  http://world-en.openfoodfacts.org/product/0000...
# 1       0000000024600  http://world-en.openfoodfacts.org/product/0000...
# 2       0000000036252  http://world-en.openfoodfacts.org/product/0000...
# 3       0000000039259  http://world-en.openfoodfacts.org/product/0000...
# 4       0000000039529  http://world-en.openfoodfacts.org/product/0000...
#
#            creator   created_t      created_datetime last_modified_t  \
# 0  date-limite-app  1447004364  2015-11-08T17:39:24Z      1447004364
# 1  date-limite-app  1434530704  2015-06-17T08:45:04Z      1434535914
# 2          tacinte  1422221701  2015-01-25T21:35:01Z      1422221855
# 3          tacinte  1422221773  2015-01-25T21:36:13Z      1422221926
# 4         teolemon  1420147051  2015-01-01T21:17:31Z      1439141740
#
#   last_modified_datetime            product_name generic_name quantity  \
# 0   2015-11-08T17:39:24Z  Poêlée à la sarladaise          NaN      NaN
# 1   2015-06-17T10:11:54Z           Filet de bœuf          NaN  2.46 kg
# 2   2015-01-25T21:37:35Z          Lion Peanut x2          NaN      NaN
# 3   2015-01-25T21:38:46Z                 Twix x2          NaN      NaN
# 4   2015-08-09T17:35:40Z          Pack de 2 Twix          NaN      NaN
#
#             ...           caffeine_100g taurine_100g ph_100g  \
# 0           ...                     NaN          NaN     NaN
# 1           ...                     NaN          NaN     NaN
# 2           ...                     NaN          NaN     NaN
# 3           ...                     NaN          NaN     NaN
# 4           ...                     NaN          NaN     NaN
#
#   fruits_vegetables_nuts_100g collagen_meat_protein_ratio_100g cocoa_100g  \
# 0                         NaN                              NaN        NaN
# 1                         NaN                              NaN        NaN
# 2                         NaN                              NaN        NaN
# 3                         NaN                              NaN        NaN
# 4                         NaN                              NaN        NaN
#
#   chlorophyl_100g carbon_footprint_100g nutrition_score_fr_100g  \
# 0             NaN                   NaN                     NaN
# 1             NaN                   NaN                     NaN
# 2             NaN                   NaN                     NaN
# 3             NaN                   NaN                     NaN
# 4             NaN                   NaN                     NaN
#
#   nutrition_score_uk_100g
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 159 columns]

# %%
usa_data = utils.getByCountry(data, 'United States')
print usa_data.shape
# Out:
# (2508, 159)

# %%
usa_data.describe()
# Out:
#        no_nutriments  additives_n  ingredients_from_palm_oil_n  \
# count            0.0  1052.000000                  1052.000000
# mean             NaN     2.180608                     0.000951
# std              NaN     2.779168                     0.030831
# min              NaN     0.000000                     0.000000
# 25%              NaN     0.000000                     0.000000
# 50%              NaN     1.000000                     0.000000
# 75%              NaN     3.000000                     0.000000
# max              NaN    17.000000                     1.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                              1052.000000
# mean                         NaN                                 0.021863
# std                          NaN                                 0.146306
# min                          NaN                                 0.000000
# 25%                          NaN                                 0.000000
# 50%                          NaN                                 0.000000
# 75%                          NaN                                 0.000000
# max                          NaN                                 1.000000
#
#        ingredients_that_may_be_from_palm_oil  nutrition_grade_uk  energy_100g  \
# count                                    0.0                 0.0  1189.000000
# mean                                     NaN                 NaN  1176.289537
# std                                      NaN                 NaN   834.188753
# min                                      NaN                 NaN     0.000000
# 25%                                      NaN                 NaN   328.000000
# 50%                                      NaN                 NaN  1290.000000
# 75%                                      NaN                 NaN  1790.000000
# max                                      NaN                 NaN  3766.000000
#
#        energy_from_fat_100g     fat_100g           ...             \
# count            727.000000  1202.000000           ...
# mean             579.689216    13.638052           ...
# std              696.134198    18.230727           ...
# min                0.000000     0.000000           ...
# 25%               43.800000     0.000000           ...
# 50%              300.000000     6.250000           ...
# 75%              917.000000    21.400000           ...
# max             3740.000000   100.000000           ...
#
#        caffeine_100g  taurine_100g  ph_100g  fruits_vegetables_nuts_100g  \
# count       4.000000           0.0      0.0                     3.000000
# mean        0.013477           NaN      NaN                    33.333333
# std         0.005561           NaN      NaN                    31.754265
# min         0.007830           NaN      NaN                    15.000000
# 25%         0.009143           NaN      NaN                    15.000000
# 50%         0.013790           NaN      NaN                    15.000000
# 75%         0.018125           NaN      NaN                    42.500000
# max         0.018500           NaN      NaN                    70.000000
#
#        collagen_meat_protein_ratio_100g  cocoa_100g  chlorophyl_100g  \
# count                               0.0         1.0              0.0
# mean                                NaN        60.0              NaN
# std                                 NaN         NaN              NaN
# min                                 NaN        60.0              NaN
# 25%                                 NaN        60.0              NaN
# 50%                                 NaN        60.0              NaN
# 75%                                 NaN        60.0              NaN
# max                                 NaN        60.0              NaN
#
#        carbon_footprint_100g  nutrition_score_fr_100g  nutrition_score_uk_100g
# count               2.000000              1026.000000              1026.000000
# mean               68.500000                 9.060429                 8.935673
# std                79.903066                 9.135097                 9.348419
# min                12.000000               -10.000000               -10.000000
# 25%                40.250000                 0.000000                 0.000000
# 50%                68.500000                10.000000                 9.000000
# 75%                96.750000                16.000000                17.000000
# max               125.000000                29.000000                29.000000
#
# [8 rows x 103 columns]

# %% [markdown]
# ### What is the most sugary food?

# %%
sugar = usa_data.sugars_100g[usa_data.sugars_100g.notnull()]
most_sugar = sugar.sort_values(ascending=False).iloc[0]
usa_data[usa_data.sugars_100g == 100.0]
# Out:
#                 code                                                url  \
# 47379  4902124680235  http://world-en.openfoodfacts.org/product/4902...
#
#         creator   created_t      created_datetime last_modified_t  \
# 47379  stephane  1438876475  2015-08-06T15:54:35Z      1439069028
#
#       last_modified_datetime product_name generic_name        quantity  \
# 47379   2015-08-08T21:23:48Z  Super Lemon  Lemon candy  2.92 oz (83 g)
#
#                 ...           caffeine_100g taurine_100g ph_100g  \
# 47379           ...                     NaN          NaN     NaN
#
#       fruits_vegetables_nuts_100g collagen_meat_protein_ratio_100g cocoa_100g  \
# 47379                         NaN                              NaN        NaN
#
#       chlorophyl_100g carbon_footprint_100g nutrition_score_fr_100g  \
# 47379             NaN                   NaN                    14.0
#
#       nutrition_score_uk_100g
# 47379                    14.0
#
# [1 rows x 159 columns]

# %% [markdown]
# ### Compare countries by average of different nutriments

# %%
data.countries_en.unique()
# Out:
# array(['France', 'United Kingdom', 'Spain', 'United States', 'Germany',
#        'France,United Kingdom', nan, 'Switzerland', 'Australia',
#        'France,United States', 'Canada', 'R\xc3\xa9union', 'Brazil',
#        'Saudi Arabia', 'Moldova', 'Belgium', 'Iraq', 'Singapore', 'Taiwan',
#        'Australia,New Zealand,Singapore,Thailand', 'Panama', 'Netherlands',
#        'China', 'Denmark,Spain', 'United Arab Emirates', 'Mexico',
#        'New Caledonia', 'El Salvador', 'Luxembourg', 'Cuba', 'Kuwait',
#        'France,United Kingdom,United States', 'Philippines', 'Aruba',
#        'Mongolia', 'Canada,United States',
#        'Australia,France,United Kingdom', 'Lebanon', 'Dominican Republic',
#        'Austria', 'Sweden', 'Guinea', 'Hong Kong', 'Costa Rica', 'Israel',
#        'China,Switzerland', 'Martinique', 'Saint Pierre and Miquelon',
#        'Thailand', 'fr:Quebec', 'Czech Republic', 'Italy',
#        'Canada,fr:Quebec', 'Canada,Portugal',
#        'France,Spain,United Kingdom', 'Indonesia', 'Armenia',
#        "C\xc3\xb4te d'Ivoire", 'Poland', 'Greece',
#        'India,United Kingdom,United States', 'French Polynesia', 'Hawaii',
#        'Ireland', 'India', 'Ecuador', 'Cambodia', 'Australia,France',
#        'Belgium,France', 'France,Netherlands', 'Algeria',
#        'Czech Republic,United Kingdom', 'Denmark',
#        'Australia,Indonesia,United States', 'Australia,Indonesia',
#        'Romania', 'Hong Kong,United States', 'France,Italy',
#        'United Kingdom,United States', 'Burundi', 'Qatar',
#        'France,R\xc3\xa9union', 'France,fr:Europe', 'France,French Guiana',
#        'Australia,United States', 'Morocco', 'France,Switzerland',
#        'Belgium,Switzerland', 'French Guiana', 'Egypt', 'Japan', 'An',
#        'Bulgaria', 'Australia,Philippines', 'France,Japan',
#        'Algeria,France', 'Portugal', 'Russia', 'Guadeloupe',
#        'Denmark,France,United Kingdom',
#        'Finland,Portugal,Spain,Sweden,United Kingdom',
#        'Lithuania,United Kingdom', 'South Korea',
#        'Portugal,Spain,United Kingdom', 'Senegal', 'France,Senegal',
#        'Belize', 'Tunisia', 'European Union',
#        'France,Switzerland,fr:Europe', 'Spain,es:Europe',
#        'Belgium,France,Germany,Netherlands', 'Slovenia', 'Germany,Spain',
#        'Other-\xd8\xa7\xd9\x84\xd8\xb9\xd8\xb1\xd8\xa7\xd9\x82', 'Togo',
#        'Chile', 'Iceland', 'Germany,Switzerland', 'Belgium,Germany',
#        'Belgium,France,Germany,Switzerland',
#        'Germany,United Kingdom,United States',
#        'Austria,Germany,Netherlands', 'Australia,Germany', 'Turkey',
#        'Spain,United States', 'France,Germany,Spain', 'France,Spain',
#        'Hungary', 'France,Germany,Romania,Scotland,United Kingdom',
#        'France,Germany', 'France,Morocco', 'South Africa',
#        'Scotland,United Kingdom', 'Belgium,France,Germany',
#        'France,Portugal', 'Austria,France,Germany,Italy,Switzerland',
#        'Belgium,France,Germany,Ireland,Netherlands,Portugal,Spain,United Kingdom',
#        'Albania', 'France,Germany,United Kingdom',
#        'Belgium,France,Germany,Italy,Netherlands',
#        'Germany,United Kingdom', 'Croatia', 'Switzerland,United States',
#        'Belgium,Netherlands', 'France,Guadeloupe',
#        'Belgium,France,Switzerland', 'Denmark,France', 'France,Monaco',
#        'France,Saint Pierre and Miquelon', 'Kazakhstan',
#        'France,Luxembourg', 'en:fresh-foods', 'en:dairies',
#        'fr:yaourt-veloute-aux-fruits', 'Mali', 'Gabon',
#        'Republic of the Congo', 'France,Germany,Portugal',
#        'France,Tunisia', 'Denmark,France,Spain',
#        'Denmark,France,Spain,United Kingdom',
#        'Denmark,Switzerland,United Kingdom',
#        'Denmark,France,Switzerland,United Kingdom', 'France,Sweden',
#        'Denmark,Portugal', 'Portugal,Spain', 'Canada,France', 'Monaco',
#        'Belgium,France,Germany,Italy,Netherlands,Portugal,Spain,Switzerland,United Kingdom',
#        'France,Portugal,Spain', 'Iran',
#        'French Guiana,Guadeloupe,Martinique', 'France,Russia',
#        'France,Martinique', 'France,New Caledonia', 'Denmark,Germany',
#        'Sint Maarten', 'Denmark,United Kingdom',
#        'Belgium,France,Luxembourg',
#        'Canada,France,Greece,Netherlands,Spain,United Kingdom,United States',
#        'Guadeloupe,Martinique', 'France,Portugal,Spain,United Kingdom',
#        'Mayotte', 'France,Netherlands,Switzerland',
#        'Belgium,France,Luxembourg,Switzerland', 'China,France',
#        'Denmark,Guadeloupe', 'France,Italy,Spain',
#        'France,United Arab Emirates',
#        'Algeria,Belgium,Canada,France,Morocco,Switzerland',
#        'France,Greece,Netherlands', 'Niger',
#        'Belgium,France,Italy,United Kingdom',
#        'France,Italy,Netherlands,United Kingdom', 'Mauritius',
#        'Denmark,France,Germany', 'Belgium,Denmark,France,Germany',
#        'Australia,Czech Republic,France',
#        'Denmark,France,Germany,United Kingdom',
#        'Czech Republic,Denmark,France,Germany', 'Austria,Germany',
#        'Belarus', 'Australia,Belgium,France',
#        'Australia,Germany,Netherlands', 'Germany,Netherlands',
#        'Mauritania', 'France,Germany,Italy', 'Finland', 'Germany,Poland',
#        'Belgium,Denmark', 'France,Romania', 'France,Saudi Arabia',
#        'Pakistan', 'Ukraine', 'France,India',
#        'Finland,France,Greece,Italy,Spain,Sweden', 'Slovakia',
#        'France,Germany,Switzerland', 'fr:\xe6\x97\xa5\xe6\x9c\xac',
#        '\xe6\x97\xa5\xe6\x9c\xac', 'Japan,\xe6\x97\xa5\xe6\x9c\xac',
#        'Finland,France', 'France,Taiwan', 'Other-japon',
#        'Republique-de-chine', 'Latvia', 'Lithuania,Sweden', 'Lithuania',
#        'France,Sri Lanka', 'Singapore,Thailanda',
#        'Other-\xe6\x97\xa5\xe6\x9c\xac', 'Macau',
#        'Other-other-\xe6\x97\xa5\xe6\x9c\xac,Other-\xe6\x97\xa5\xe6\x9c\xac',
#        'Mozambique', 'Australia,United Kingdom,United States',
#        'Algeria,Egypt,Morocco,Qatar,Tunisia,United Arab Emirates',
#        'Denmark,France,Portugal,Switzerland',
#        'United Kingdom,fr:Angleterre', 'Australia,United Kingdom',
#        'France,Germany,Netherlands,United Kingdom', 'Argentina', 'Cyprus',
#        'Peru', 'Germany,Switzerland,United Kingdom', 'Malaysia',
#        'Poland,United Kingdom',
#        'Belgium,France,Greece,Netherlands,Portugal', 'Irlande', 'Malta',
#        'France,Italy,United Kingdom', 'Democratic Republic of the Congo',
#        'Belgium,Finland,France,Germany,Greece,Italy,Portugal,Spain',
#        'Belgium,fr:Europe',
#        'Belgium,France,Italy,Luxembourg,Netherlands,Spain',
#        'Belgium,France,Germany,Italy,Spain', 'Denmark,France,Portugal',
#        'Denmark,France,Switzerland',
#        'Belgium,France,Netherlands,Switzerland',
#        'France,Germany,Italy,Norway,Spain,Sweden,United Kingdom',
#        'Belgium,Czech Republic,Denmark,France,Germany,Italy,Netherlands,New Zealand,Spain,Sweden,United Kingdom',
#        'Belgium,France,Netherlands,United Kingdom', 'Belgium,Portugal',
#        'Belgium,France,Italy,Spain',
#        'Albania,Belgium,France,Germany,Italy,Netherlands,Spain',
#        'Belgium,France,Germany,Hungary,Italy,Netherlands,Spain,United Kingdom',
#        'Belgium,France,Italy,Netherlands,Spain,United Kingdom',
#        'Belgium,France,Germany,Hungary,Italy,Netherlands,Spain',
#        'Belgium,France,Italy,Netherlands,Portugal,Spain,United Kingdom',
#        'France,Italy,Luxembourg,Netherlands,Spain',
#        'Belgium,Denmark,Finland,France,Germany,Hungary,Italy,Netherlands,Norway,Spain,Sweden,United Kingdom',
#        'Belgium,France,Netherlands,Spain,United Kingdom',
#        'Belgium,France,Germany,Netherlands,Spain,Switzerland,United Kingdom',
#        'Belgium,Finland,France,Italy,Netherlands,Spain,Sweden',
#        'Belgium,France,Germany,Hungary,Switzerland',
#        'Belgium,France,Hungary,Italy,fr:Quebec',
#        'Belgium,France,Luxembourg,Netherlands,United Kingdom',
#        'Belgium,Finland,France,Italy,Spain', 'Belgium,France,Russia',
#        'Belgium,France,Italy', 'European Union,France',
#        'Belgium,France,United Kingdom', 'Czech Republic,Slovakia',
#        'Czech Republic,France,Iraq',
#        'Belgium,France,Spain,Switzerland,United Kingdom', 'France,Kuwait',
#        'France,Poland', 'Czech Republic,France', 'Denmark,Sweden',
#        'Switzerland,United Kingdom', 'Polska', 'Moldova,United States',
#        'Ghana', 'Belgium,United States', 'Kenya', 'Tanzania',
#        'France,Mauritius', 'Burkina Faso', 'Brunei', 'Jordan',
#        'Azerbaijan', 'Qatar,Saudi Arabia,United Arab Emirates',
#        'Lebanon,Qatar,Syria,Tunisia,Yemen', 'Norway', 'Vanuatu',
#        'Colombia', 'France,Norway', 'Greece,Israel', 'Estonia',
#        'Finland,France,Sweden,United Kingdom',
#        'France,Guadeloupe,Italy,Netherlands,Norway,Sweden,Switzerland,United Kingdom',
#        'Guatemala', 'Venezuela', 'France,Serbia', 'Andorra,France',
#        'Bahrain', 'Bulgaria,France', 'Belgium,France,Netherlands',
#        'Austria,France,United Kingdom', 'Argentina,France',
#        'Argentina,Saudi Arabia', 'Brazil,France', 'Albania,Italy',
#        'Denmark,R\xc3\xa9union', 'Denmark,France,Italy,United Kingdom',
#        'Denmark,Italy', 'Croatia,Portugal', 'Albania,Denmark,Italy',
#        'Italy,Romania', 'Belgium,Italy', 'Georgia',
#        'France,Switzerland,United States', 'Italy,Spain',
#        'France,Germany,Greece,Sweden,United Kingdom',
#        'Denmark,Finland,France,Germany,Hungary,Italy,Netherlands,Norway,Portugal,Russia,Slovenia,Spain,Sweden,United Kingdom',
#        'Guadeloupe,Slovenia,United Kingdom', 'China,Denmark',
#        'Germany,Italy', 'Czech Republic,Italy', 'New Zealand',
#        'France,Italy,Serbia,Spain', 'Cook Islands',
#        'Austria,France,Germany,Morocco,Netherlands,United Kingdom',
#        'Andorra', 'Belgium,France,Spain', 'Andorra,Spain', 'Morocco,Spain',
#        'Serbia', 'Germany,Turkey', 'Other-turquie',
#        'France,Netherlands,Spain,United Kingdom', 'Germany,Greece,Spain',
#        'France,Greece', 'Nederland', 'Spain,fr:Europe',
#        'Canada,France,Germany,United Kingdom',
#        'Australia,Thailand,United Kingdom',
#        'France,Thailand,United Kingdom', 'Cambodia,Thailand',
#        'France,Ireland,United Kingdom', 'Vietnam',
#        'France,Hungary,United Kingdom', 'Thailand,United Kingdom',
#        'Austria,France', 'Egypt,United Kingdom,United States',
#        'Austria,Germany,Spain', 'France,French Polynesia,New Caledonia',
#        'Australia,New Zealand', 'Bangladesh', 'Australia,Japan',
#        'Maldives', 'Australia,Malaysia', 'China,Hong Kong'], dtype=object)

# %%
countries = ['India', 'Poland', 'Spain', 'United States', 'France', 'United Kingdom', 'China', 'Canada', 'Switzerland', 'Germany', 'Brazil', 'South Korea']

# %%
def getAvg(dataset, nutriment):
    return dataset[nutriment][dataset[nutriment].notnull()].mean()

# %%
def compareCountriesByNutrimentAverage(data, countries, nutriment):
    df = pd.DataFrame(index=['average'], columns=countries)
    for i in range(len(countries)):
        country = countries[i]
        country_data = utils.getByCountry(data, country)
        df[country] = getAvg(country_data, nutriment)
    return df

# %%
df = compareCountriesByNutrimentAverage(data, countries, 'sugars_100g')
print df
# Out:
#          India     Poland      Spain  United States     France  \
# average   16.7  15.402564  10.480405      16.605626  12.664608
#
#          United Kingdom  China     Canada  Switzerland    Germany  Brazil  \
# average       16.716583    1.3  18.307119    13.665368  13.104298  22.051
#
#          South Korea
# average          5.0

# %%
df.plot(kind='bar')
